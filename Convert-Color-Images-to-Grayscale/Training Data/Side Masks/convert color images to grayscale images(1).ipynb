# %% [markdown]
# 1. loop over each image file name in the loaded list from the s3 bucket
# 2. check the image is already in grayscale or black and white
# 3. if image is already from grayscale, keep it as it is
# 4. if image is color, convert it to grayscale
# 5. save the converted image from the same file name as a png file

# %% [markdown]
# Step 1 – Install required packages

# %%
#install boto3 and pillow 
# !pip install boto3 pillow
# Out:
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.40.69)
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (12.0.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.69 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.40.69)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (1.26.20)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)

# %% [markdown]
# Step 2 - Import libraries and load image names from S3

# %%
# import boto3 to access AWS S3
import boto3

# import UNSIGNED and Config to allow public S3 access without credentials
from botocore import UNSIGNED
from botocore.client import Config

# import os to work with directories and file paths
import os

# import io to work with in-memory byte streams
import io

# import Image from Pillow to handle image operations
from PIL import Image

# set the S3 bucket name
BUCKET = "amazon-bodym"

# set the prefix (folder path) inside the bucket where images are stored
PREFIX = "train/mask_left/"

# create an S3 client with unsigned (public) access
s3 = boto3.client("s3", config=Config(signature_version=UNSIGNED))

# create an empty list to store image file names
image_mask = []

# create a paginator to list many objects in the S3 folder
paginator = s3.get_paginator("list_objects_v2")

# loop through each page of results from the paginator
for page in paginator.paginate(Bucket=BUCKET, Prefix=PREFIX):
    # get the list of objects on this page (or empty list if none)
    for obj in page.get("Contents", []):
        # get the full key (path + file name) of the object
        key = obj["Key"]
        # check if the key ends with a common image extension
        if key.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff", ".webp")):
            # take only the file name (last part after '/')
            filename_only = key.rsplit("/", 1)[-1]
            # add the file name to the list
            image_mask.append(filename_only)

# remove duplicates and sort the list of image names
image_mask = sorted(set(image_mask))

# print how many image names were loaded
print(len(image_mask), "names loaded")
# Out:
# 6134 names loaded

# %% [markdown]
# Step 3 - Create the output folder

# %%
# set the name of the output folder for processed images
output_folder = "side masked images"

# create the folder if it does not already exist
os.makedirs(output_folder, exist_ok=True)

# print the path of the output folder
print("Output folder:", output_folder)
# Out:
# Output folder: side masked images

# %% [markdown]
# Step 4 - Download, check color vs grayscale, convert if needed, and save as PNG

# %%
# loop over each image file name in the list
for filename in image_mask:
    # build the full S3 key by joining prefix and file name
    s3_key = f"{PREFIX}{filename}"
    
    # print the file being processed (optional)
    print("Processing:", s3_key)
    
    # get the image object from S3
    response = s3.get_object(Bucket=BUCKET, Key=s3_key)
    
    # read the image bytes from the response body
    img_bytes = response["Body"].read()
    
    # wrap the bytes in a BytesIO object so Pillow can open it
    img_stream = io.BytesIO(img_bytes)
    
    # open the image using Pillow
    img = Image.open(img_stream)
    
    # check if the image is already grayscale or black and white
    # "L" and "1" are common modes for grayscale / bilevel images
    if img.mode in ("L", "1"):
        # if the image is already grayscale, keep it as it is
        gray_img = img
    else:
        # if the image is color (e.g., "RGB", "RGBA"), convert it to grayscale
        gray_img = img.convert("L")
    
    # get the base name without the extension (e.g., "0001" from "0001.png")
    base_name = os.path.splitext(filename)[0]
    
    # create the new file name with .png extension
    new_filename = base_name + ".png"
    
    # build the full output path inside the output folder
    output_path = os.path.join(output_folder, new_filename)
    
    # save the grayscale image as a PNG file at the output path
    gray_img.save(output_path, format="PNG")
    
    # optional: print the saved file path
    print("Saved to:", output_path)

# print a final message when all images are done
print("All images processed and saved in:", output_folder)
# Out:
# Processing: train/mask_left/001f3a88501980a5eca6f6346a0ca8d9.png
# Saved to: side masked images/001f3a88501980a5eca6f6346a0ca8d9.png
# Processing: train/mask_left/0023f967e5089c95ae22c43e25b2cef1.png
# Saved to: side masked images/0023f967e5089c95ae22c43e25b2cef1.png
# Processing: train/mask_left/0026b236ae6f63db9c354cc2916c9c34.png
# Saved to: side masked images/0026b236ae6f63db9c354cc2916c9c34.png
# Processing: train/mask_left/003d4db18f3359c8ed8410817b726539.png
# Saved to: side masked images/003d4db18f3359c8ed8410817b726539.png
# Processing: train/mask_left/004c72a4efa6341764e10e6f599d4212.png
# Saved to: side masked images/004c72a4efa6341764e10e6f599d4212.png
# Processing: train/mask_left/005e8eca196e8127de2fa342ccf6a007.png
# Saved to: side masked images/005e8eca196e8127de2fa342ccf6a007.png
# Processing: train/mask_left/006269330d4250ea76578c935d09b700.png
# Saved to: side masked images/006269330d4250ea76578c935d09b700.png
# Processing: train/mask_left/0063d101686814661ad13e8b71e7a20f.png
# Saved to: side masked images/0063d101686814661ad13e8b71e7a20f.png
# Processing: train/mask_left/007e27ae1b23ff14d51cf4fcd2a308e5.png
# Saved to: side masked images/007e27ae1b23ff14d51cf4fcd2a308e5.png
# Processing: train/mask_left/007ec205cc5dd598e68659994b7fc508.png
# Saved to: side masked images/007ec205cc5dd598e68659994b7fc508.png
# Processing: train/mask_left/0093da086599ed038737bb1c8c724697.png
# Saved to: side masked images/0093da086599ed038737bb1c8c724697.png
# Processing: train/mask_left/00a19f879a88dafab8af4eabbfef045a.png
# Saved to: side masked images/00a19f879a88dafab8af4eabbfef045a.png
# Processing: train/mask_left/00bb4d84c9cf8903eeb0671eb66bd739.png
# Saved to: side masked images/00bb4d84c9cf8903eeb0671eb66bd739.png
# Processing: train/mask_left/00e41e2dfd7b6110d0533280665fc9a2.png
# Saved to: side masked images/00e41e2dfd7b6110d0533280665fc9a2.png
# Processing: train/mask_left/00eacdd1f9d8d1d01475e73e7152efe9.png
# Saved to: side masked images/00eacdd1f9d8d1d01475e73e7152efe9.png
# Processing: train/mask_left/00f0c3ff479a6b27658d147ac8f002fb.png
# Saved to: side masked images/00f0c3ff479a6b27658d147ac8f002fb.png
# Processing: train/mask_left/00f1d9af65333bedb6bbd77d49171ff4.png
# Saved to: side masked images/00f1d9af65333bedb6bbd77d49171ff4.png
# Processing: train/mask_left/00f33d68beefd6928dbbc1df5027e1c4.png
# Saved to: side masked images/00f33d68beefd6928dbbc1df5027e1c4.png
# Processing: train/mask_left/00f990c2bc7c8e9fab68aa0f0b8ddb3f.png
# Saved to: side masked images/00f990c2bc7c8e9fab68aa0f0b8ddb3f.png
# Processing: train/mask_left/010191c608385f7e97afed2d59ac471b.png
# Saved to: side masked images/010191c608385f7e97afed2d59ac471b.png
# Processing: train/mask_left/0122fc59d2e51f43615c3f4b4b95589a.png
# Saved to: side masked images/0122fc59d2e51f43615c3f4b4b95589a.png
# Processing: train/mask_left/0127d26e27927942c1e18785e0831f17.png
# Saved to: side masked images/0127d26e27927942c1e18785e0831f17.png
# Processing: train/mask_left/012a5c6ed67366227e94b1feacb459c6.png
# Saved to: side masked images/012a5c6ed67366227e94b1feacb459c6.png
# Processing: train/mask_left/012ca70a651b0bc2e37b1eca204bb12c.png
# Saved to: side masked images/012ca70a651b0bc2e37b1eca204bb12c.png
# Processing: train/mask_left/0137443ba49903cceede13e710c77634.png
# Saved to: side masked images/0137443ba49903cceede13e710c77634.png
# Processing: train/mask_left/013f653fc8fe7e729e75b1f3c13eb9fa.png
# Saved to: side masked images/013f653fc8fe7e729e75b1f3c13eb9fa.png
# Processing: train/mask_left/013f966ffdec4f00a1de9496b3bb14c7.png
# Saved to: side masked images/013f966ffdec4f00a1de9496b3bb14c7.png
# Processing: train/mask_left/014167c885a3eccd271e1cd4bb21cacf.png
# Saved to: side masked images/014167c885a3eccd271e1cd4bb21cacf.png
# Processing: train/mask_left/0148f4b177b6d6e07ee086cd56a11675.png
# Saved to: side masked images/0148f4b177b6d6e07ee086cd56a11675.png
# Processing: train/mask_left/014ccba9cc82c5550b42e586d6793562.png
# Saved to: side masked images/014ccba9cc82c5550b42e586d6793562.png
# Processing: train/mask_left/0157a94959b0633597a30b4b19d49ef1.png
# Saved to: side masked images/0157a94959b0633597a30b4b19d49ef1.png
# Processing: train/mask_left/015a93aa9265f25f7033402ec8e3652a.png
# Saved to: side masked images/015a93aa9265f25f7033402ec8e3652a.png
# Processing: train/mask_left/016a974731334cbdb587c6a9c12527b4.png
# Saved to: side masked images/016a974731334cbdb587c6a9c12527b4.png
# Processing: train/mask_left/0182acba9ce97abb60387d37023856bc.png
# Saved to: side masked images/0182acba9ce97abb60387d37023856bc.png
# Processing: train/mask_left/01950e4d973a635218a6144592c5ef31.png
# Saved to: side masked images/01950e4d973a635218a6144592c5ef31.png
# Processing: train/mask_left/01b52f95df5c9b96e509db11bedc3d5b.png
# Saved to: side masked images/01b52f95df5c9b96e509db11bedc3d5b.png
# Processing: train/mask_left/01ba31dc23d1d3b10f5e5a0eec601a6b.png
# Saved to: side masked images/01ba31dc23d1d3b10f5e5a0eec601a6b.png
# Processing: train/mask_left/01bdf71817337f95176d224eff873782.png
# Saved to: side masked images/01bdf71817337f95176d224eff873782.png
# Processing: train/mask_left/01e09f8bc11aaf8e7bb071577c6aad6c.png
# Saved to: side masked images/01e09f8bc11aaf8e7bb071577c6aad6c.png
# Processing: train/mask_left/01e38f7a517646adf8411cae63f77b48.png
# Saved to: side masked images/01e38f7a517646adf8411cae63f77b48.png
# Processing: train/mask_left/01e3ce18c227e7a0b07deb28173a7578.png
# Saved to: side masked images/01e3ce18c227e7a0b07deb28173a7578.png
# Processing: train/mask_left/01ec2085a12d883610f6bddf662d43aa.png
# Saved to: side masked images/01ec2085a12d883610f6bddf662d43aa.png
# Processing: train/mask_left/02135bca568f12f0f8d9549fe9f9345c.png
# Saved to: side masked images/02135bca568f12f0f8d9549fe9f9345c.png
# Processing: train/mask_left/0269b7a56a4d4a94db90455f34b61c8b.png
# Saved to: side masked images/0269b7a56a4d4a94db90455f34b61c8b.png
# Processing: train/mask_left/0273bdca946df4eafa1977f1370384fa.png
# Saved to: side masked images/0273bdca946df4eafa1977f1370384fa.png
# Processing: train/mask_left/027a6a0f5f038262fd3bd41b7ef21ce0.png
# Saved to: side masked images/027a6a0f5f038262fd3bd41b7ef21ce0.png
# Processing: train/mask_left/0293748d12b9a69a53285bfe60b8a037.png
# Saved to: side masked images/0293748d12b9a69a53285bfe60b8a037.png
# Processing: train/mask_left/0298657f8403f0962ffc00019c99f15e.png
# Saved to: side masked images/0298657f8403f0962ffc00019c99f15e.png
# Processing: train/mask_left/02a73e623751f3840181eca89b0709b2.png
# Saved to: side masked images/02a73e623751f3840181eca89b0709b2.png
# Processing: train/mask_left/02c007b09805464807072fc6167a48dd.png
# Saved to: side masked images/02c007b09805464807072fc6167a48dd.png
# Processing: train/mask_left/02c74f804d0c0df70f2e89c2af6fde01.png
# Saved to: side masked images/02c74f804d0c0df70f2e89c2af6fde01.png
# Processing: train/mask_left/02cd1b8abd5505481ee0d1b88d62d73d.png
# Saved to: side masked images/02cd1b8abd5505481ee0d1b88d62d73d.png
# Processing: train/mask_left/02e000919e1add9732acbd6c3e6c3d98.png
# Saved to: side masked images/02e000919e1add9732acbd6c3e6c3d98.png
# Processing: train/mask_left/02fc12013b666d5dd8ae3342ffc1658b.png
# Saved to: side masked images/02fc12013b666d5dd8ae3342ffc1658b.png
# Processing: train/mask_left/030524f16f0c99436dd150d826076ab3.png
# Saved to: side masked images/030524f16f0c99436dd150d826076ab3.png
# Processing: train/mask_left/030ef1c4c2470832c99b5ae6655af58c.png
# Saved to: side masked images/030ef1c4c2470832c99b5ae6655af58c.png
# Processing: train/mask_left/03177e0110de38b90959d15adf8fac5d.png
# Saved to: side masked images/03177e0110de38b90959d15adf8fac5d.png
# Processing: train/mask_left/0317be5e1d9beb8f272d4c3d83a8e516.png
# Saved to: side masked images/0317be5e1d9beb8f272d4c3d83a8e516.png
# Processing: train/mask_left/03233d491b0914acc97f5b7e55aed1f9.png
# Saved to: side masked images/03233d491b0914acc97f5b7e55aed1f9.png
# Processing: train/mask_left/032ad9b33b85a05be80cc36f9c1ea62e.png
# Saved to: side masked images/032ad9b33b85a05be80cc36f9c1ea62e.png
# Processing: train/mask_left/032de8cbe627f498f5eef00d2cb38a06.png
# Saved to: side masked images/032de8cbe627f498f5eef00d2cb38a06.png
# Processing: train/mask_left/033cbc0bd426984172b57b0be76201b3.png
# Saved to: side masked images/033cbc0bd426984172b57b0be76201b3.png
# Processing: train/mask_left/0347898b2e3f7aa483185c22c3a82648.png
# Saved to: side masked images/0347898b2e3f7aa483185c22c3a82648.png
# Processing: train/mask_left/034a71aae00bdba256c93025fc6fa9c2.png
# Saved to: side masked images/034a71aae00bdba256c93025fc6fa9c2.png
# Processing: train/mask_left/03506e92ab2c616969f5dd37a6e95c92.png
# Saved to: side masked images/03506e92ab2c616969f5dd37a6e95c92.png
# Processing: train/mask_left/0386d340d9af7b0c356133cf8cba002d.png
# Saved to: side masked images/0386d340d9af7b0c356133cf8cba002d.png
# Processing: train/mask_left/03897fed846f9c0423173eb0deaeec63.png
# Saved to: side masked images/03897fed846f9c0423173eb0deaeec63.png
# Processing: train/mask_left/0398cf57d6de526ed721d5a9b5bd908d.png
# Saved to: side masked images/0398cf57d6de526ed721d5a9b5bd908d.png
# Processing: train/mask_left/03b953ddd4eccdf1052b814477add966.png
# Saved to: side masked images/03b953ddd4eccdf1052b814477add966.png
# Processing: train/mask_left/03c1f83986b5347f071d29b1e22e8577.png
# Saved to: side masked images/03c1f83986b5347f071d29b1e22e8577.png
# Processing: train/mask_left/03c56b3babc7eb149e13600bd2425bd4.png
# Saved to: side masked images/03c56b3babc7eb149e13600bd2425bd4.png
# Processing: train/mask_left/03c7f2ec6f04f86544653efb6ede232e.png
# Saved to: side masked images/03c7f2ec6f04f86544653efb6ede232e.png
# Processing: train/mask_left/03d3d203a017940e72288f1163d68e99.png
# Saved to: side masked images/03d3d203a017940e72288f1163d68e99.png
# Processing: train/mask_left/03e209219f767381152f56f908803db6.png
# Saved to: side masked images/03e209219f767381152f56f908803db6.png
# Processing: train/mask_left/03e3fa514fd93f168e1ee1035d6e3643.png
# Saved to: side masked images/03e3fa514fd93f168e1ee1035d6e3643.png
# Processing: train/mask_left/03e5aed6f09cf36a6b9e72d141322023.png
# Saved to: side masked images/03e5aed6f09cf36a6b9e72d141322023.png
# Processing: train/mask_left/03f78a14c316d5b747f29b2709173019.png
# Saved to: side masked images/03f78a14c316d5b747f29b2709173019.png
# Processing: train/mask_left/03f92cd461c39b84bc7eceb26989fada.png
# Saved to: side masked images/03f92cd461c39b84bc7eceb26989fada.png
# Processing: train/mask_left/03fae319b61295cae7dd52675b9d3c0e.png
# Saved to: side masked images/03fae319b61295cae7dd52675b9d3c0e.png
# Processing: train/mask_left/03fb2d286d459c230006a332d14f71b4.png
# Saved to: side masked images/03fb2d286d459c230006a332d14f71b4.png
# Processing: train/mask_left/04016043ca2efd75939a0d7d65c6d99d.png
# Saved to: side masked images/04016043ca2efd75939a0d7d65c6d99d.png
# Processing: train/mask_left/04121a94c9566505f87ae382273a8235.png
# Saved to: side masked images/04121a94c9566505f87ae382273a8235.png
# Processing: train/mask_left/04306e036df32d2d112ec6c9d34b26be.png
# Saved to: side masked images/04306e036df32d2d112ec6c9d34b26be.png
# Processing: train/mask_left/043e0f84792df2dc8b55d2fafabec4d6.png
# Saved to: side masked images/043e0f84792df2dc8b55d2fafabec4d6.png
# Processing: train/mask_left/0467a051b0514f99ad90a84fd357f52d.png
# Saved to: side masked images/0467a051b0514f99ad90a84fd357f52d.png
# Processing: train/mask_left/0467c9e24375f921c3ac34fab4949942.png
# Saved to: side masked images/0467c9e24375f921c3ac34fab4949942.png
# Processing: train/mask_left/0471f4df298f55928935aacd2be59d7b.png
# Saved to: side masked images/0471f4df298f55928935aacd2be59d7b.png
# Processing: train/mask_left/0483694f1c63c7249d65d757dd2d3d07.png
# Saved to: side masked images/0483694f1c63c7249d65d757dd2d3d07.png
# Processing: train/mask_left/04842d3a2f339b05d9efa296d2e0ea21.png
# Saved to: side masked images/04842d3a2f339b05d9efa296d2e0ea21.png
# Processing: train/mask_left/048632a24e7a9104b5227da2e942c719.png
# Saved to: side masked images/048632a24e7a9104b5227da2e942c719.png
# Processing: train/mask_left/048a44c1711a32f449ff93d0c8a542f3.png
# Saved to: side masked images/048a44c1711a32f449ff93d0c8a542f3.png
# Processing: train/mask_left/048e6c8b034e100404db1191e628aa17.png
# Saved to: side masked images/048e6c8b034e100404db1191e628aa17.png
# Processing: train/mask_left/049e2f6c6ca086972310a00143f56697.png
# Saved to: side masked images/049e2f6c6ca086972310a00143f56697.png
# Processing: train/mask_left/04a8b8286e19d3892b5026d4941e4dd5.png
# Saved to: side masked images/04a8b8286e19d3892b5026d4941e4dd5.png
# Processing: train/mask_left/04bf3d906949d7375fc4b0706cbdc90e.png
# Saved to: side masked images/04bf3d906949d7375fc4b0706cbdc90e.png
# Processing: train/mask_left/04c1e42250a9459278422e0ed48c2776.png
# Saved to: side masked images/04c1e42250a9459278422e0ed48c2776.png
# Processing: train/mask_left/04c96a7665f8fe1e22eab1fccdfe1319.png
# Saved to: side masked images/04c96a7665f8fe1e22eab1fccdfe1319.png
# Processing: train/mask_left/04ca320d904cc0beac5560cf6c2d6edd.png
# Saved to: side masked images/04ca320d904cc0beac5560cf6c2d6edd.png
# Processing: train/mask_left/04dbf7b7e587a4b2a900b81c0520931b.png
# Saved to: side masked images/04dbf7b7e587a4b2a900b81c0520931b.png
# Processing: train/mask_left/04e4a8603bce2e5c9bbf532e437e4ce2.png
# Saved to: side masked images/04e4a8603bce2e5c9bbf532e437e4ce2.png
# Processing: train/mask_left/04e8425eee9f5c769ad8430ebb8b79d4.png
# Saved to: side masked images/04e8425eee9f5c769ad8430ebb8b79d4.png
# Processing: train/mask_left/04ffb18e4870f00b57a4545f2c200691.png
# Saved to: side masked images/04ffb18e4870f00b57a4545f2c200691.png
# Processing: train/mask_left/050100de67cabd3e1df0dbe746f89efd.png
# Saved to: side masked images/050100de67cabd3e1df0dbe746f89efd.png
# Processing: train/mask_left/0504222db0ed524f013971eae7b7973f.png
# Saved to: side masked images/0504222db0ed524f013971eae7b7973f.png
# Processing: train/mask_left/0508ce41ce91957a114985abe4c4ca34.png
# Saved to: side masked images/0508ce41ce91957a114985abe4c4ca34.png
# Processing: train/mask_left/050b324c4425dc9f5ecb0e34a0c123ae.png
# Saved to: side masked images/050b324c4425dc9f5ecb0e34a0c123ae.png
# Processing: train/mask_left/051ead3c068b0ee0e22981e9f64f0963.png
# Saved to: side masked images/051ead3c068b0ee0e22981e9f64f0963.png
# Processing: train/mask_left/052b7e059ec26b5329054dbf4cd3ec55.png
# Saved to: side masked images/052b7e059ec26b5329054dbf4cd3ec55.png
# Processing: train/mask_left/053801f2c9e9da710115b6454c6d6747.png
# Saved to: side masked images/053801f2c9e9da710115b6454c6d6747.png
# Processing: train/mask_left/054214eeeb331fb3e11b00cb02e26b08.png
# Saved to: side masked images/054214eeeb331fb3e11b00cb02e26b08.png
# Processing: train/mask_left/0572d6f3d0cc196b87f7f013d89e74ad.png
# Saved to: side masked images/0572d6f3d0cc196b87f7f013d89e74ad.png
# Processing: train/mask_left/059dfdef03225feaef0a4facae589405.png
# Saved to: side masked images/059dfdef03225feaef0a4facae589405.png
# Processing: train/mask_left/05b19174e300ef525e78dac3e90758be.png
# Saved to: side masked images/05b19174e300ef525e78dac3e90758be.png
# Processing: train/mask_left/05be671d99c6f9823342c689c1efe76f.png
# Saved to: side masked images/05be671d99c6f9823342c689c1efe76f.png
# Processing: train/mask_left/05c609c2e68926db5770077cffdccf54.png
# Saved to: side masked images/05c609c2e68926db5770077cffdccf54.png
# Processing: train/mask_left/05cce109b81bbf80bef46aa45a4d2ebd.png
# Saved to: side masked images/05cce109b81bbf80bef46aa45a4d2ebd.png
# Processing: train/mask_left/05d04bb91809cb2084cfdb32f12868b5.png
# Saved to: side masked images/05d04bb91809cb2084cfdb32f12868b5.png
# Processing: train/mask_left/05e3a51107defec6c8a217c041ac86a8.png
# Saved to: side masked images/05e3a51107defec6c8a217c041ac86a8.png
# Processing: train/mask_left/05f7cd33d784ba1de0af501c4c8d4108.png
# Saved to: side masked images/05f7cd33d784ba1de0af501c4c8d4108.png
# Processing: train/mask_left/05f8ad70f1cefe14f8fe46e9c28139e5.png
# Saved to: side masked images/05f8ad70f1cefe14f8fe46e9c28139e5.png
# Processing: train/mask_left/05fcda51734c28ea92ca15cb3017ce14.png
# Saved to: side masked images/05fcda51734c28ea92ca15cb3017ce14.png
# Processing: train/mask_left/05feab8b556ff72ef100dfbc0c0f1434.png
# Saved to: side masked images/05feab8b556ff72ef100dfbc0c0f1434.png
# Processing: train/mask_left/060338f7e0a22e1dbb6b9446b8c034e5.png
# Saved to: side masked images/060338f7e0a22e1dbb6b9446b8c034e5.png
# Processing: train/mask_left/06082036c6e0b65139f18847fac16b00.png
# Saved to: side masked images/06082036c6e0b65139f18847fac16b00.png
# Processing: train/mask_left/06087c26b13f87b25ae591ec3d5bd3d4.png
# Saved to: side masked images/06087c26b13f87b25ae591ec3d5bd3d4.png
# Processing: train/mask_left/0609fb4c565895f2ba0e60e7ae9d15f1.png
# Saved to: side masked images/0609fb4c565895f2ba0e60e7ae9d15f1.png
# Processing: train/mask_left/0623f7138742b7f5703be8c637de65f5.png
# Saved to: side masked images/0623f7138742b7f5703be8c637de65f5.png
# Processing: train/mask_left/06284964e245e85c88a24e8036f36ddc.png
# Saved to: side masked images/06284964e245e85c88a24e8036f36ddc.png
# Processing: train/mask_left/062af5169e1e3e3f76162826166dd883.png
# Saved to: side masked images/062af5169e1e3e3f76162826166dd883.png
# Processing: train/mask_left/062eae309555bef2b5ed2086d01aac70.png
# Saved to: side masked images/062eae309555bef2b5ed2086d01aac70.png
# Processing: train/mask_left/0630f88dc2ad1b52e64ae9ca0199138d.png
# Saved to: side masked images/0630f88dc2ad1b52e64ae9ca0199138d.png
# Processing: train/mask_left/0635244b1a23cafa1fe9b7815c95aa88.png
# Saved to: side masked images/0635244b1a23cafa1fe9b7815c95aa88.png
# Processing: train/mask_left/064688cc59fd5272a4f02a56943c32eb.png
# Saved to: side masked images/064688cc59fd5272a4f02a56943c32eb.png
# Processing: train/mask_left/0646b203554ad6151c04cbb32490ca34.png
# Saved to: side masked images/0646b203554ad6151c04cbb32490ca34.png
# Processing: train/mask_left/0661f175eb9bd1f3f3f5630ea3181062.png
# Saved to: side masked images/0661f175eb9bd1f3f3f5630ea3181062.png
# Processing: train/mask_left/0664127259cf1d3f1d92a32962787ed5.png
# Saved to: side masked images/0664127259cf1d3f1d92a32962787ed5.png
# Processing: train/mask_left/0665da56f8dbfcb15dc2719bbbcf0687.png
# Saved to: side masked images/0665da56f8dbfcb15dc2719bbbcf0687.png
# Processing: train/mask_left/0667cf2683167bb30384a6b8e0f0835c.png
# Saved to: side masked images/0667cf2683167bb30384a6b8e0f0835c.png
# Processing: train/mask_left/066c79e9179162fbbb12d0d103ffcdc5.png
# Saved to: side masked images/066c79e9179162fbbb12d0d103ffcdc5.png
# Processing: train/mask_left/067432336ed417450d020c7d73ef9dc2.png
# Saved to: side masked images/067432336ed417450d020c7d73ef9dc2.png
# Processing: train/mask_left/068051c7f63783e7451df23258144183.png
# Saved to: side masked images/068051c7f63783e7451df23258144183.png
# Processing: train/mask_left/0691a095be93424d0e4d033bb3361d50.png
# Saved to: side masked images/0691a095be93424d0e4d033bb3361d50.png
# Processing: train/mask_left/0699770d4d3727e1f6cc71131b3407f4.png
# Saved to: side masked images/0699770d4d3727e1f6cc71131b3407f4.png
# Processing: train/mask_left/06a764e280828cd424205a5227b4138e.png
# Saved to: side masked images/06a764e280828cd424205a5227b4138e.png
# Processing: train/mask_left/06bf7206e43770bd59b5242e6e6e77b0.png
# Saved to: side masked images/06bf7206e43770bd59b5242e6e6e77b0.png
# Processing: train/mask_left/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
# Saved to: side masked images/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
# Processing: train/mask_left/06dce778fd7c65b00599dff9c775572c.png
# Saved to: side masked images/06dce778fd7c65b00599dff9c775572c.png
# Processing: train/mask_left/06e45b55f5adde24e3a9f636a4419acc.png
# Saved to: side masked images/06e45b55f5adde24e3a9f636a4419acc.png
# Processing: train/mask_left/06e9f45b52599f16505a62e02cf2ac77.png
# Saved to: side masked images/06e9f45b52599f16505a62e02cf2ac77.png
# Processing: train/mask_left/06f1ea8825f3af6867cd32df8a3571e3.png
# Saved to: side masked images/06f1ea8825f3af6867cd32df8a3571e3.png
# Processing: train/mask_left/07084298bc8c61c0e470c5a22dd802ef.png
# Saved to: side masked images/07084298bc8c61c0e470c5a22dd802ef.png
# Processing: train/mask_left/0711d230975b698d3a752e8e47ff81d4.png
# Saved to: side masked images/0711d230975b698d3a752e8e47ff81d4.png
# Processing: train/mask_left/071e71f599f0e5c89928bb3faa33900b.png
# Saved to: side masked images/071e71f599f0e5c89928bb3faa33900b.png
# Processing: train/mask_left/073923d9d64a63eb03ddde128a34fa72.png
# Saved to: side masked images/073923d9d64a63eb03ddde128a34fa72.png
# Processing: train/mask_left/073a2e9f5b21609553cfd1ef10e5817f.png
# Saved to: side masked images/073a2e9f5b21609553cfd1ef10e5817f.png
# Processing: train/mask_left/075a9c411feae3c3e7e66b62992974d5.png
# Saved to: side masked images/075a9c411feae3c3e7e66b62992974d5.png
# Processing: train/mask_left/0765ffd2473e26b2630f45597b6efd83.png
# Saved to: side masked images/0765ffd2473e26b2630f45597b6efd83.png
# Processing: train/mask_left/0771b02749e1ad9dac6ff111c027466d.png
# Saved to: side masked images/0771b02749e1ad9dac6ff111c027466d.png
# Processing: train/mask_left/077684ba01a8c91e34f4220265f65923.png
# Saved to: side masked images/077684ba01a8c91e34f4220265f65923.png
# Processing: train/mask_left/07838cf039c5ca8e0d17c3825cfcdc66.png
# Saved to: side masked images/07838cf039c5ca8e0d17c3825cfcdc66.png
# Processing: train/mask_left/078e6b66f8b3aa8b1c00c42a697d0277.png
# Saved to: side masked images/078e6b66f8b3aa8b1c00c42a697d0277.png
# Processing: train/mask_left/07a701d17c0a7d71554e2739fec0689b.png
# Saved to: side masked images/07a701d17c0a7d71554e2739fec0689b.png
# Processing: train/mask_left/07ab9b2c2e1af5006beca03ccfd8eb1c.png
# Saved to: side masked images/07ab9b2c2e1af5006beca03ccfd8eb1c.png
# Processing: train/mask_left/07aeb5983a8afb2c5509a03f42d9cd1f.png
# Saved to: side masked images/07aeb5983a8afb2c5509a03f42d9cd1f.png
# Processing: train/mask_left/07b8cd30daae23f6b1b9280f8c2212f6.png
# Saved to: side masked images/07b8cd30daae23f6b1b9280f8c2212f6.png
# Processing: train/mask_left/07ba11aae450b0acba269eeb8d3309bb.png
# Saved to: side masked images/07ba11aae450b0acba269eeb8d3309bb.png
# Processing: train/mask_left/07bf2f074922e107181b6c028505cfc2.png
# Saved to: side masked images/07bf2f074922e107181b6c028505cfc2.png
# Processing: train/mask_left/07e1ad567cf1af383e236e9880011a74.png
# Saved to: side masked images/07e1ad567cf1af383e236e9880011a74.png
# Processing: train/mask_left/07e40d5b514b2785938b0cfae03d0046.png
# Saved to: side masked images/07e40d5b514b2785938b0cfae03d0046.png
# Processing: train/mask_left/07ff1d0aef9d5190e92cca6d1b588d08.png
# Saved to: side masked images/07ff1d0aef9d5190e92cca6d1b588d08.png
# Processing: train/mask_left/07ff9029c75a830172da89eb078ca475.png
# Saved to: side masked images/07ff9029c75a830172da89eb078ca475.png
# Processing: train/mask_left/07ffff824d0c3516525af58bfb3bd4e6.png
# Saved to: side masked images/07ffff824d0c3516525af58bfb3bd4e6.png
# Processing: train/mask_left/0804929db7e417cf86c113727a3809cd.png
# Saved to: side masked images/0804929db7e417cf86c113727a3809cd.png
# Processing: train/mask_left/080acc8fe1b480a6e78cc7e12b2b0674.png
# Saved to: side masked images/080acc8fe1b480a6e78cc7e12b2b0674.png
# Processing: train/mask_left/081c764b70905170efc0aaa4d7089b42.png
# Saved to: side masked images/081c764b70905170efc0aaa4d7089b42.png
# Processing: train/mask_left/0825898edf6a31f74fed0c56274b7207.png
# Saved to: side masked images/0825898edf6a31f74fed0c56274b7207.png
# Processing: train/mask_left/082643cec8cc39f87efaa74268974022.png
# Saved to: side masked images/082643cec8cc39f87efaa74268974022.png
# Processing: train/mask_left/0827f7f3cc986ded54e573cf237da769.png
# Saved to: side masked images/0827f7f3cc986ded54e573cf237da769.png
# Processing: train/mask_left/084193770b05e5cc7bfa842da16f6ab2.png
# Saved to: side masked images/084193770b05e5cc7bfa842da16f6ab2.png
# Processing: train/mask_left/084a938ea27cfe695205db36f9ad3145.png
# Saved to: side masked images/084a938ea27cfe695205db36f9ad3145.png
# Processing: train/mask_left/084f9a30019d2dfd814ed2c72da1190d.png
# Saved to: side masked images/084f9a30019d2dfd814ed2c72da1190d.png
# Processing: train/mask_left/08632570302905702d74fa5e8065a5d8.png
# Saved to: side masked images/08632570302905702d74fa5e8065a5d8.png
# Processing: train/mask_left/086ea485e526496aa81d0de48b93dea7.png
# Saved to: side masked images/086ea485e526496aa81d0de48b93dea7.png
# Processing: train/mask_left/087a62c3ab7405992cdb9026a68d1f60.png
# Saved to: side masked images/087a62c3ab7405992cdb9026a68d1f60.png
# Processing: train/mask_left/08876890daf4c1f29b1df5b60157e92f.png
# Saved to: side masked images/08876890daf4c1f29b1df5b60157e92f.png
# Processing: train/mask_left/088ebf237aa59e8094bfeebe49f9ab4a.png
# Saved to: side masked images/088ebf237aa59e8094bfeebe49f9ab4a.png
# Processing: train/mask_left/089f2bb0b52165737f29242e744161b0.png
# Saved to: side masked images/089f2bb0b52165737f29242e744161b0.png
# Processing: train/mask_left/089ffa3e458c624ef0c2510c857fa1cd.png
# Saved to: side masked images/089ffa3e458c624ef0c2510c857fa1cd.png
# Processing: train/mask_left/08a13fba0d8a7ebc37c67e3fa0b9644d.png
# Saved to: side masked images/08a13fba0d8a7ebc37c67e3fa0b9644d.png
# Processing: train/mask_left/08a84e5302bc2a212b8fbb69b27afeb2.png
# Saved to: side masked images/08a84e5302bc2a212b8fbb69b27afeb2.png
# Processing: train/mask_left/08c51c607cd17e5b8da9c746178858e6.png
# Saved to: side masked images/08c51c607cd17e5b8da9c746178858e6.png
# Processing: train/mask_left/08c91bdf0901111efbac55765a74b3a1.png
# Saved to: side masked images/08c91bdf0901111efbac55765a74b3a1.png
# Processing: train/mask_left/08cd22497989b5491b0922c097c8095a.png
# Saved to: side masked images/08cd22497989b5491b0922c097c8095a.png
# Processing: train/mask_left/08cef385e069470b9212d99a55fe577a.png
# Saved to: side masked images/08cef385e069470b9212d99a55fe577a.png
# Processing: train/mask_left/08df0a55a08b7d54cf5065924c6ed519.png
# Saved to: side masked images/08df0a55a08b7d54cf5065924c6ed519.png
# Processing: train/mask_left/08e62633e15c223d4a2401d9c5b5f950.png
# Saved to: side masked images/08e62633e15c223d4a2401d9c5b5f950.png
# Processing: train/mask_left/08edf08c12fcf48e46b3e1971e2fb3fc.png
# Saved to: side masked images/08edf08c12fcf48e46b3e1971e2fb3fc.png
# Processing: train/mask_left/08ef9d2ad566e0615228f0df8837559e.png
# Saved to: side masked images/08ef9d2ad566e0615228f0df8837559e.png
# Processing: train/mask_left/08fdbfcfd9ac4b3001de464364b0c451.png
# Saved to: side masked images/08fdbfcfd9ac4b3001de464364b0c451.png
# Processing: train/mask_left/0904f25147f31b8cc4f5ba1e0bb60b14.png
# Saved to: side masked images/0904f25147f31b8cc4f5ba1e0bb60b14.png
# Processing: train/mask_left/091dcce1c6acbac0fa26446a342bfc7f.png
# Saved to: side masked images/091dcce1c6acbac0fa26446a342bfc7f.png
# Processing: train/mask_left/093961965a3795f11d5eb1d24a84fc02.png
# Saved to: side masked images/093961965a3795f11d5eb1d24a84fc02.png
# Processing: train/mask_left/095069c883b63791487728742a523807.png
# Saved to: side masked images/095069c883b63791487728742a523807.png
# Processing: train/mask_left/095feb5e348946e7059b54d9bbd50fe5.png
# Saved to: side masked images/095feb5e348946e7059b54d9bbd50fe5.png
# Processing: train/mask_left/097f4ea5aa26fd8b4d7ebd3fb73bd8c0.png
# Saved to: side masked images/097f4ea5aa26fd8b4d7ebd3fb73bd8c0.png
# Processing: train/mask_left/099a67cb3315d5c3797d29e5c8bd006c.png
# Saved to: side masked images/099a67cb3315d5c3797d29e5c8bd006c.png
# Processing: train/mask_left/09a138eb116df7925f0d5e58a990dcb3.png
# Saved to: side masked images/09a138eb116df7925f0d5e58a990dcb3.png
# Processing: train/mask_left/09a213c921ba40405082e94e72d57f50.png
# Saved to: side masked images/09a213c921ba40405082e94e72d57f50.png
# Processing: train/mask_left/09a7bfc1d5cf869911b452a5ba1c6124.png
# Saved to: side masked images/09a7bfc1d5cf869911b452a5ba1c6124.png
# Processing: train/mask_left/09ab1de2320fe3497769c7d6a8b963da.png
# Saved to: side masked images/09ab1de2320fe3497769c7d6a8b963da.png
# Processing: train/mask_left/09bd430b26bf7e8939ba9e37823dd877.png
# Saved to: side masked images/09bd430b26bf7e8939ba9e37823dd877.png
# Processing: train/mask_left/09bebe55b31bf31879da21d42be9b85d.png
# Saved to: side masked images/09bebe55b31bf31879da21d42be9b85d.png
# Processing: train/mask_left/09d2bee2bc4927f2a7ab4edc318ce555.png
# Saved to: side masked images/09d2bee2bc4927f2a7ab4edc318ce555.png
# Processing: train/mask_left/09dbaa3516f1c83387ee81521782fd8d.png
# Saved to: side masked images/09dbaa3516f1c83387ee81521782fd8d.png
# Processing: train/mask_left/09ec6927f8d675f821c9abc8e1a4d5c6.png
# Saved to: side masked images/09ec6927f8d675f821c9abc8e1a4d5c6.png
# Processing: train/mask_left/09eeab1cf8ec6752583b934f5f5454e8.png
# Saved to: side masked images/09eeab1cf8ec6752583b934f5f5454e8.png
# Processing: train/mask_left/09f359f49ffb393fe45c406971508edf.png
# Saved to: side masked images/09f359f49ffb393fe45c406971508edf.png
# Processing: train/mask_left/0a0684e65aedceed1c530331de5c5c7e.png
# Saved to: side masked images/0a0684e65aedceed1c530331de5c5c7e.png
# Processing: train/mask_left/0a0b4bf37aea2ee106a9e313c4cbc510.png
# Saved to: side masked images/0a0b4bf37aea2ee106a9e313c4cbc510.png
# Processing: train/mask_left/0a106bdbef36f07eff3015993baddb77.png
# Saved to: side masked images/0a106bdbef36f07eff3015993baddb77.png
# Processing: train/mask_left/0a1bc69ee91c46b9f25c214c432554e5.png
# Saved to: side masked images/0a1bc69ee91c46b9f25c214c432554e5.png
# Processing: train/mask_left/0a44f2ea5ca1b122ab4a2b979ed72be4.png
# Saved to: side masked images/0a44f2ea5ca1b122ab4a2b979ed72be4.png
# Processing: train/mask_left/0a5434c7c6cb555985d493d9d5127cb9.png
# Saved to: side masked images/0a5434c7c6cb555985d493d9d5127cb9.png
# Processing: train/mask_left/0a5781c1d28a2d641f06411e110cc9a2.png
# Saved to: side masked images/0a5781c1d28a2d641f06411e110cc9a2.png
# Processing: train/mask_left/0a603b774953fdc4ff904046fbe08789.png
# Saved to: side masked images/0a603b774953fdc4ff904046fbe08789.png
# Processing: train/mask_left/0a75742c1295f983763de472bc93931f.png
# Saved to: side masked images/0a75742c1295f983763de472bc93931f.png
# Processing: train/mask_left/0a78cbb5bde1989be0c81d7a9f008f70.png
# Saved to: side masked images/0a78cbb5bde1989be0c81d7a9f008f70.png
# Processing: train/mask_left/0a7a70f022269b970f5612044eacc221.png
# Saved to: side masked images/0a7a70f022269b970f5612044eacc221.png
# Processing: train/mask_left/0a8202989125aafc65a439143f02af25.png
# Saved to: side masked images/0a8202989125aafc65a439143f02af25.png
# Processing: train/mask_left/0a83628753d7e722527429bcf1baaa3c.png
# Saved to: side masked images/0a83628753d7e722527429bcf1baaa3c.png
# Processing: train/mask_left/0aabe3fa55df08982395d2afb0d63760.png
# Saved to: side masked images/0aabe3fa55df08982395d2afb0d63760.png
# Processing: train/mask_left/0aac68fa8fdd5d84c799f5cf69d53d71.png
# Saved to: side masked images/0aac68fa8fdd5d84c799f5cf69d53d71.png
# Processing: train/mask_left/0ab1b0b72dcc493fd91712eea928b6f0.png
# Saved to: side masked images/0ab1b0b72dcc493fd91712eea928b6f0.png
# Processing: train/mask_left/0ab973f5dfc92c30154714ae6db62c22.png
# Saved to: side masked images/0ab973f5dfc92c30154714ae6db62c22.png
# Processing: train/mask_left/0abbdd1dc3254c8ceccd2573db377920.png
# Saved to: side masked images/0abbdd1dc3254c8ceccd2573db377920.png
# Processing: train/mask_left/0ac04adb9fbcdc66301e2ee3e5adcdcb.png
# Saved to: side masked images/0ac04adb9fbcdc66301e2ee3e5adcdcb.png
# Processing: train/mask_left/0acb9353f78e039dce9e39ebfd1d89f4.png
# Saved to: side masked images/0acb9353f78e039dce9e39ebfd1d89f4.png
# Processing: train/mask_left/0acda68ed877759619d7d72fbb5b4155.png
# Saved to: side masked images/0acda68ed877759619d7d72fbb5b4155.png
# Processing: train/mask_left/0acf802c948af5eaf60f00107e6b3c57.png
# Saved to: side masked images/0acf802c948af5eaf60f00107e6b3c57.png
# Processing: train/mask_left/0ad3cd583e7ac4aa628c1b059f609041.png
# Saved to: side masked images/0ad3cd583e7ac4aa628c1b059f609041.png
# Processing: train/mask_left/0b04f95f3472e99ea1c981207599e937.png
# Saved to: side masked images/0b04f95f3472e99ea1c981207599e937.png
# Processing: train/mask_left/0b0b63ba87bab764bf8eeb8f60907ee2.png
# Saved to: side masked images/0b0b63ba87bab764bf8eeb8f60907ee2.png
# Processing: train/mask_left/0b0c7f943e3411c3ca161573230578ae.png
# Saved to: side masked images/0b0c7f943e3411c3ca161573230578ae.png
# Processing: train/mask_left/0b147bd8e330d49af51b3d68a8e67376.png
# Saved to: side masked images/0b147bd8e330d49af51b3d68a8e67376.png
# Processing: train/mask_left/0b16380bc9ca269804868f718dd6ff95.png
# Saved to: side masked images/0b16380bc9ca269804868f718dd6ff95.png
# Processing: train/mask_left/0b2b20ad685152b5d8e2a7b21f98f638.png
# Saved to: side masked images/0b2b20ad685152b5d8e2a7b21f98f638.png
# Processing: train/mask_left/0b4b2c38e7acc9f9f052d8800b106e58.png
# Saved to: side masked images/0b4b2c38e7acc9f9f052d8800b106e58.png
# Processing: train/mask_left/0b4d267e879475e304136741fefbabb7.png
# Saved to: side masked images/0b4d267e879475e304136741fefbabb7.png
# Processing: train/mask_left/0b6483c8674d09602d2b8cb6e5c9edff.png
# Saved to: side masked images/0b6483c8674d09602d2b8cb6e5c9edff.png
# Processing: train/mask_left/0b6c7d9c9c9bcb180b1ed2e55c71d944.png
# Saved to: side masked images/0b6c7d9c9c9bcb180b1ed2e55c71d944.png
# Processing: train/mask_left/0b76b03034f0774b7d6569395164f124.png
# Saved to: side masked images/0b76b03034f0774b7d6569395164f124.png
# Processing: train/mask_left/0b76da5015c803aa52d261c68ef80d2d.png
# Saved to: side masked images/0b76da5015c803aa52d261c68ef80d2d.png
# Processing: train/mask_left/0b8b88c9a9abeceb321afa6f0416b48e.png
# Saved to: side masked images/0b8b88c9a9abeceb321afa6f0416b48e.png
# Processing: train/mask_left/0b8fa4d88d8a238a483d382b8f787372.png
# Saved to: side masked images/0b8fa4d88d8a238a483d382b8f787372.png
# Processing: train/mask_left/0bb817bd90fe6905706c34a7929e991c.png
# Saved to: side masked images/0bb817bd90fe6905706c34a7929e991c.png
# Processing: train/mask_left/0bc1c97be6cfb2ac29639c1c3be1ec60.png
# Saved to: side masked images/0bc1c97be6cfb2ac29639c1c3be1ec60.png
# Processing: train/mask_left/0bc77bb6478d5299d03a505b93caedc3.png
# Saved to: side masked images/0bc77bb6478d5299d03a505b93caedc3.png
# Processing: train/mask_left/0bed0dfee690d94d94172675a1387321.png
# Saved to: side masked images/0bed0dfee690d94d94172675a1387321.png
# Processing: train/mask_left/0bf690034c82135d188815bf2fc6c2d5.png
# Saved to: side masked images/0bf690034c82135d188815bf2fc6c2d5.png
# Processing: train/mask_left/0c04352beb4c66741b179414518a4cf5.png
# Saved to: side masked images/0c04352beb4c66741b179414518a4cf5.png
# Processing: train/mask_left/0c0ebb29d40801fadfa8d0079e20d853.png
# Saved to: side masked images/0c0ebb29d40801fadfa8d0079e20d853.png
# Processing: train/mask_left/0c1b986bbab782da04fcc983a68e95a2.png
# Saved to: side masked images/0c1b986bbab782da04fcc983a68e95a2.png
# Processing: train/mask_left/0c20fb636bc2d5e8933cb6e72046bd9c.png
# Saved to: side masked images/0c20fb636bc2d5e8933cb6e72046bd9c.png
# Processing: train/mask_left/0c2b97a8cdd2dd168d3bc51aae3572dd.png
# Saved to: side masked images/0c2b97a8cdd2dd168d3bc51aae3572dd.png
# Processing: train/mask_left/0c40850ea8514316a1f85000c46b0dd8.png
# Saved to: side masked images/0c40850ea8514316a1f85000c46b0dd8.png
# Processing: train/mask_left/0c537504a2c039f0a3411c030aff105c.png
# Saved to: side masked images/0c537504a2c039f0a3411c030aff105c.png
# Processing: train/mask_left/0c57c3b6153298c601b17f5b0bb8970b.png
# Saved to: side masked images/0c57c3b6153298c601b17f5b0bb8970b.png
# Processing: train/mask_left/0c59beda104dcc1a52e8141a0fec204f.png
# Saved to: side masked images/0c59beda104dcc1a52e8141a0fec204f.png
# Processing: train/mask_left/0c60a867eac27ae952fe5fe20ca0b777.png
# Saved to: side masked images/0c60a867eac27ae952fe5fe20ca0b777.png
# Processing: train/mask_left/0c72cb743b36d5df45809f79b51d27f6.png
# Saved to: side masked images/0c72cb743b36d5df45809f79b51d27f6.png
# Processing: train/mask_left/0c77a03d5c1d38c29dfbf188b48a175a.png
# Saved to: side masked images/0c77a03d5c1d38c29dfbf188b48a175a.png
# Processing: train/mask_left/0c7d6cc8bb7506aa119f85570306897e.png
# Saved to: side masked images/0c7d6cc8bb7506aa119f85570306897e.png
# Processing: train/mask_left/0c97f07558c5bd2509927218cb2a9354.png
# Saved to: side masked images/0c97f07558c5bd2509927218cb2a9354.png
# Processing: train/mask_left/0caabd8260f5aae50dfb6c9131180dc9.png
# Saved to: side masked images/0caabd8260f5aae50dfb6c9131180dc9.png
# Processing: train/mask_left/0cb41d46064db656b7b17c5430891b64.png
# Saved to: side masked images/0cb41d46064db656b7b17c5430891b64.png
# Processing: train/mask_left/0ccb41003f26db68b10f61881ba773e9.png
# Saved to: side masked images/0ccb41003f26db68b10f61881ba773e9.png
# Processing: train/mask_left/0cd4afb56ddea190206ad70ab7be8b89.png
# Saved to: side masked images/0cd4afb56ddea190206ad70ab7be8b89.png
# Processing: train/mask_left/0ce4ff10e43be9b75a7f65dbae5c356f.png
# Saved to: side masked images/0ce4ff10e43be9b75a7f65dbae5c356f.png
# Processing: train/mask_left/0ced81848d2988c32095ab677562a550.png
# Saved to: side masked images/0ced81848d2988c32095ab677562a550.png
# Processing: train/mask_left/0d041ffd4c4773b5066c5059c7859117.png
# Saved to: side masked images/0d041ffd4c4773b5066c5059c7859117.png
# Processing: train/mask_left/0d04e46b5ddfd9e17e7b6ab78f4a30ed.png
# Saved to: side masked images/0d04e46b5ddfd9e17e7b6ab78f4a30ed.png
# Processing: train/mask_left/0d0b6179d54bdad8e5d51a1cc9110aa2.png
# Saved to: side masked images/0d0b6179d54bdad8e5d51a1cc9110aa2.png
# Processing: train/mask_left/0d1494b76d8a7833cd3a404a23a5f35e.png
# Saved to: side masked images/0d1494b76d8a7833cd3a404a23a5f35e.png
# Processing: train/mask_left/0d227c97fcb7267b124584c54a5b5058.png
# Saved to: side masked images/0d227c97fcb7267b124584c54a5b5058.png
# Processing: train/mask_left/0d22d63a7f682ac90f5a92949786d43c.png
# Saved to: side masked images/0d22d63a7f682ac90f5a92949786d43c.png
# Processing: train/mask_left/0d2af7c22dad2ee4940c259ffd4a63e2.png
# Saved to: side masked images/0d2af7c22dad2ee4940c259ffd4a63e2.png
# Processing: train/mask_left/0d474f70f15f2ab4a6a90ee9d81d6629.png
# Saved to: side masked images/0d474f70f15f2ab4a6a90ee9d81d6629.png
# Processing: train/mask_left/0d4a37b1a4f3c3472c33bf6fef730999.png
# Saved to: side masked images/0d4a37b1a4f3c3472c33bf6fef730999.png
# Processing: train/mask_left/0d4a9cce6294a2bdc6dae93d0d9c42a8.png
# Saved to: side masked images/0d4a9cce6294a2bdc6dae93d0d9c42a8.png
# Processing: train/mask_left/0d4d63e31b84b6dba7cb4df0d9c40ef5.png
# Saved to: side masked images/0d4d63e31b84b6dba7cb4df0d9c40ef5.png
# Processing: train/mask_left/0d4da626480f3e137ed86955fd51a7fa.png
# Saved to: side masked images/0d4da626480f3e137ed86955fd51a7fa.png
# Processing: train/mask_left/0d7093197a5aa643f4a4f4272129485b.png
# Saved to: side masked images/0d7093197a5aa643f4a4f4272129485b.png
# Processing: train/mask_left/0d7576af9fa91e149a2707b92fa3525e.png
# Saved to: side masked images/0d7576af9fa91e149a2707b92fa3525e.png
# Processing: train/mask_left/0d7fc1d684010e23a96bd392a6f24160.png
# Saved to: side masked images/0d7fc1d684010e23a96bd392a6f24160.png
# Processing: train/mask_left/0d881f6dc8c93ba2685897cf83ca098a.png
# Saved to: side masked images/0d881f6dc8c93ba2685897cf83ca098a.png
# Processing: train/mask_left/0d8c4ca2910d54ef3c8e07a7db775714.png
# Saved to: side masked images/0d8c4ca2910d54ef3c8e07a7db775714.png
# Processing: train/mask_left/0d95143c71cdba00ddfdfde3c5ed3736.png
# Saved to: side masked images/0d95143c71cdba00ddfdfde3c5ed3736.png
# Processing: train/mask_left/0d9541c8bb2a3b08696c868a2f367b28.png
# Saved to: side masked images/0d9541c8bb2a3b08696c868a2f367b28.png
# Processing: train/mask_left/0d9619e185d0421de616f25435c1fe71.png
# Saved to: side masked images/0d9619e185d0421de616f25435c1fe71.png
# Processing: train/mask_left/0d9ef51d391d90554e370442df708aba.png
# Saved to: side masked images/0d9ef51d391d90554e370442df708aba.png
# Processing: train/mask_left/0dae6c437ef95bda0fab02c286e4f027.png
# Saved to: side masked images/0dae6c437ef95bda0fab02c286e4f027.png
# Processing: train/mask_left/0db6842427a22e6febbac76e230d7b0c.png
# Saved to: side masked images/0db6842427a22e6febbac76e230d7b0c.png
# Processing: train/mask_left/0dbab72235925b802d4d6eb7da73f877.png
# Saved to: side masked images/0dbab72235925b802d4d6eb7da73f877.png
# Processing: train/mask_left/0dbdb6cb1d8a06b5d04af2da9a6b1b6a.png
# Saved to: side masked images/0dbdb6cb1d8a06b5d04af2da9a6b1b6a.png
# Processing: train/mask_left/0dc18ed0520e04a93507325fffaa2180.png
# Saved to: side masked images/0dc18ed0520e04a93507325fffaa2180.png
# Processing: train/mask_left/0dc528625358e346f87979bd8d343757.png
# Saved to: side masked images/0dc528625358e346f87979bd8d343757.png
# Processing: train/mask_left/0dc9f0002a2e532011b6917132246b7d.png
# Saved to: side masked images/0dc9f0002a2e532011b6917132246b7d.png
# Processing: train/mask_left/0dcb07bb38f0fc7c566e575ae60a0fd1.png
# Saved to: side masked images/0dcb07bb38f0fc7c566e575ae60a0fd1.png
# Processing: train/mask_left/0dd129cd654b1e9d8cdc16045cbdcb43.png
# Saved to: side masked images/0dd129cd654b1e9d8cdc16045cbdcb43.png
# Processing: train/mask_left/0debd935032066628001f5a0cd8ecba7.png
# Saved to: side masked images/0debd935032066628001f5a0cd8ecba7.png
# Processing: train/mask_left/0dfe027f3811e2b0c334fba8bb97fcbf.png
# Saved to: side masked images/0dfe027f3811e2b0c334fba8bb97fcbf.png
# Processing: train/mask_left/0e04785d95b059ed15dc5fef2b749e82.png
# Saved to: side masked images/0e04785d95b059ed15dc5fef2b749e82.png
# Processing: train/mask_left/0e06f4390c36c2759a3216b69fa75206.png
# Saved to: side masked images/0e06f4390c36c2759a3216b69fa75206.png
# Processing: train/mask_left/0e09297ba3ccab7460a1f1fc54eeb711.png
# Saved to: side masked images/0e09297ba3ccab7460a1f1fc54eeb711.png
# Processing: train/mask_left/0e0d40f41aa61146f2304598a4e5c9ab.png
# Saved to: side masked images/0e0d40f41aa61146f2304598a4e5c9ab.png
# Processing: train/mask_left/0e1d6010722e65dee157cc66440b68d1.png
# Saved to: side masked images/0e1d6010722e65dee157cc66440b68d1.png
# Processing: train/mask_left/0e2a0f51b8c4285ad4e113b0fe5603cf.png
# Saved to: side masked images/0e2a0f51b8c4285ad4e113b0fe5603cf.png
# Processing: train/mask_left/0e42f12bab0e1000f93711c3dc782ef6.png
# Saved to: side masked images/0e42f12bab0e1000f93711c3dc782ef6.png
# Processing: train/mask_left/0e44b0b2bb23d87a919adc1425e7e033.png
# Saved to: side masked images/0e44b0b2bb23d87a919adc1425e7e033.png
# Processing: train/mask_left/0e49ca49b712f96940b287a734a0b6ab.png
# Saved to: side masked images/0e49ca49b712f96940b287a734a0b6ab.png
# Processing: train/mask_left/0e4a0305c597e3d589aea31a5256c17f.png
# Saved to: side masked images/0e4a0305c597e3d589aea31a5256c17f.png
# Processing: train/mask_left/0e516bf3403bfecbee73398a643082b2.png
# Saved to: side masked images/0e516bf3403bfecbee73398a643082b2.png
# Processing: train/mask_left/0e53e1127aa272cb76800a0aace1918a.png
# Saved to: side masked images/0e53e1127aa272cb76800a0aace1918a.png
# Processing: train/mask_left/0e5a3f8d6a5236e335268959ba894dbe.png
# Saved to: side masked images/0e5a3f8d6a5236e335268959ba894dbe.png
# Processing: train/mask_left/0e60e89f62da8600e89839edcccfc829.png
# Saved to: side masked images/0e60e89f62da8600e89839edcccfc829.png
# Processing: train/mask_left/0e6f4232537cc56832c2ba9030ed4a42.png
# Saved to: side masked images/0e6f4232537cc56832c2ba9030ed4a42.png
# Processing: train/mask_left/0e7a6f00986f560b17e590a2866b861f.png
# Saved to: side masked images/0e7a6f00986f560b17e590a2866b861f.png
# Processing: train/mask_left/0e808ff39a47efd01dc17ed55d6b405f.png
# Saved to: side masked images/0e808ff39a47efd01dc17ed55d6b405f.png
# Processing: train/mask_left/0e8cd4618bef763dc15dd4976979bbe2.png
# Saved to: side masked images/0e8cd4618bef763dc15dd4976979bbe2.png
# Processing: train/mask_left/0e8fef1cba468d96c66b2798db767850.png
# Saved to: side masked images/0e8fef1cba468d96c66b2798db767850.png
# Processing: train/mask_left/0e951a83c2e25246d0219ac73bd7487c.png
# Saved to: side masked images/0e951a83c2e25246d0219ac73bd7487c.png
# Processing: train/mask_left/0e96f4c58e5dbed2cd4dcb104b35c854.png
# Saved to: side masked images/0e96f4c58e5dbed2cd4dcb104b35c854.png
# Processing: train/mask_left/0eb0e855323bfef4ec2b2e5be92b38e7.png
# Saved to: side masked images/0eb0e855323bfef4ec2b2e5be92b38e7.png
# Processing: train/mask_left/0ebb45d02c1f369120fb84115bb727a6.png
# Saved to: side masked images/0ebb45d02c1f369120fb84115bb727a6.png
# Processing: train/mask_left/0ec39eeacebcbec3fc7e8f17e0def85d.png
# Saved to: side masked images/0ec39eeacebcbec3fc7e8f17e0def85d.png
# Processing: train/mask_left/0ec474ac34b6f6b9775c04ca0af79061.png
# Saved to: side masked images/0ec474ac34b6f6b9775c04ca0af79061.png
# Processing: train/mask_left/0ec5f33332a8194e9d1ab087bb0b2d44.png
# Saved to: side masked images/0ec5f33332a8194e9d1ab087bb0b2d44.png
# Processing: train/mask_left/0eca47118bb162170793b7d3a173c501.png
# Saved to: side masked images/0eca47118bb162170793b7d3a173c501.png
# Processing: train/mask_left/0edc34449b10d0e364d59ae8ab24958f.png
# Saved to: side masked images/0edc34449b10d0e364d59ae8ab24958f.png
# Processing: train/mask_left/0ee380485c6e094762edd01d47251937.png
# Saved to: side masked images/0ee380485c6e094762edd01d47251937.png
# Processing: train/mask_left/0ef3e6c67d93adfd0e47dd985cbe1868.png
# Saved to: side masked images/0ef3e6c67d93adfd0e47dd985cbe1868.png
# Processing: train/mask_left/0efe0a28b638f968e6060fdeb5dd353c.png
# Saved to: side masked images/0efe0a28b638f968e6060fdeb5dd353c.png
# Processing: train/mask_left/0f132c8ceb37c7c7c5b2baec9e638b30.png
# Saved to: side masked images/0f132c8ceb37c7c7c5b2baec9e638b30.png
# Processing: train/mask_left/0f2878ec21824d939eaad8d35f04ac02.png
# Saved to: side masked images/0f2878ec21824d939eaad8d35f04ac02.png
# Processing: train/mask_left/0f2df214e5404d716a1aae72c9c20fd0.png
# Saved to: side masked images/0f2df214e5404d716a1aae72c9c20fd0.png
# Processing: train/mask_left/0f358f02d7d1650ca4867b5f17eb587f.png
# Saved to: side masked images/0f358f02d7d1650ca4867b5f17eb587f.png
# Processing: train/mask_left/0f4c1adbb25718987673881c37156f27.png
# Saved to: side masked images/0f4c1adbb25718987673881c37156f27.png
# Processing: train/mask_left/0f4c8fe7d926935b07987b7c6c5ee24d.png
# Saved to: side masked images/0f4c8fe7d926935b07987b7c6c5ee24d.png
# Processing: train/mask_left/0f50a42d6ec701e8500fbe12d5e3febc.png
# Saved to: side masked images/0f50a42d6ec701e8500fbe12d5e3febc.png
# Processing: train/mask_left/0f5331b3751cddde35d708f52c03acaa.png
# Saved to: side masked images/0f5331b3751cddde35d708f52c03acaa.png
# Processing: train/mask_left/0f59b7aeadf748461c748784785b1619.png
# Saved to: side masked images/0f59b7aeadf748461c748784785b1619.png
# Processing: train/mask_left/0f65a91579c8b894a3ae1a34237e161c.png
# Saved to: side masked images/0f65a91579c8b894a3ae1a34237e161c.png
# Processing: train/mask_left/0f67cba92529b2693839d238950f71a3.png
# Saved to: side masked images/0f67cba92529b2693839d238950f71a3.png
# Processing: train/mask_left/0f6cd39a0ecd228141a87ac1f0c76d8e.png
# Saved to: side masked images/0f6cd39a0ecd228141a87ac1f0c76d8e.png
# Processing: train/mask_left/0f805b0f74211361e3d196564ecca2d2.png
# Saved to: side masked images/0f805b0f74211361e3d196564ecca2d2.png
# Processing: train/mask_left/0f8c95c034c65f6231c7cea60881f460.png
# Saved to: side masked images/0f8c95c034c65f6231c7cea60881f460.png
# Processing: train/mask_left/0fa16515378c5d72b470d98515bc6ef2.png
# Saved to: side masked images/0fa16515378c5d72b470d98515bc6ef2.png
# Processing: train/mask_left/0fa449eb260cd7a95bcfe464aa3f9397.png
# Saved to: side masked images/0fa449eb260cd7a95bcfe464aa3f9397.png
# Processing: train/mask_left/0fa7d9bd133043e9e8cf64a73475e662.png
# Saved to: side masked images/0fa7d9bd133043e9e8cf64a73475e662.png
# Processing: train/mask_left/0fa7dbd7ca0e34a14977e9c31d7a0427.png
# Saved to: side masked images/0fa7dbd7ca0e34a14977e9c31d7a0427.png
# Processing: train/mask_left/0fb494aee4e17a1391986479811b5957.png
# Saved to: side masked images/0fb494aee4e17a1391986479811b5957.png
# Processing: train/mask_left/0fb5eb17a0a86ed631dfe6a9a98785d9.png
# Saved to: side masked images/0fb5eb17a0a86ed631dfe6a9a98785d9.png
# Processing: train/mask_left/0fba53b49b39c9ad53624ced59c2edc4.png
# Saved to: side masked images/0fba53b49b39c9ad53624ced59c2edc4.png
# Processing: train/mask_left/0fbbd17ed0384f190e78ceb8772204dd.png
# Saved to: side masked images/0fbbd17ed0384f190e78ceb8772204dd.png
# Processing: train/mask_left/0fce9db8b9bfefb783bf99ad317ab4a6.png
# Saved to: side masked images/0fce9db8b9bfefb783bf99ad317ab4a6.png
# Processing: train/mask_left/0ff808dde706b4127fe435aecfae52b8.png
# Saved to: side masked images/0ff808dde706b4127fe435aecfae52b8.png
# ...
# Saved to: side masked images/fb4e13859fcf096a1d35f6a7c42c02b0.png
# Processing: train/mask_left/fb5058cfb72dfbcb19aec409d91f0f52.png
# Saved to: side masked images/fb5058cfb72dfbcb19aec409d91f0f52.png
# Processing: train/mask_left/fb580d441990132c5e814a7cd8f20e1b.png
# Saved to: side masked images/fb580d441990132c5e814a7cd8f20e1b.png
# Processing: train/mask_left/fb5b18233378ff592b9e97a5c669b481.png
# Saved to: side masked images/fb5b18233378ff592b9e97a5c669b481.png
# Processing: train/mask_left/fb6880656cff8f9574d6b96c88ef619c.png
# Saved to: side masked images/fb6880656cff8f9574d6b96c88ef619c.png
# Processing: train/mask_left/fb701b9d8fb58b46465e7598958f1094.png
# Saved to: side masked images/fb701b9d8fb58b46465e7598958f1094.png
# Processing: train/mask_left/fb7e4caa4f71caaf9712827bb5d16ed6.png
# Saved to: side masked images/fb7e4caa4f71caaf9712827bb5d16ed6.png
# Processing: train/mask_left/fb95d9a6e3911d9ce55845af15e13113.png
# Saved to: side masked images/fb95d9a6e3911d9ce55845af15e13113.png
# Processing: train/mask_left/fba885b0c700e9bb9d3b5e7c1f51bb9e.png
# Saved to: side masked images/fba885b0c700e9bb9d3b5e7c1f51bb9e.png
# Processing: train/mask_left/fba8aab25dabb8b3f620d29e5619f385.png
# Saved to: side masked images/fba8aab25dabb8b3f620d29e5619f385.png
# Processing: train/mask_left/fbb24d1babe66cac20917490cdda0886.png
# Saved to: side masked images/fbb24d1babe66cac20917490cdda0886.png
# Processing: train/mask_left/fbbf158bc4700b8bb9685f17976d8e7d.png
# Saved to: side masked images/fbbf158bc4700b8bb9685f17976d8e7d.png
# Processing: train/mask_left/fbc5df9f15c966725250f352261672bc.png
# Saved to: side masked images/fbc5df9f15c966725250f352261672bc.png
# Processing: train/mask_left/fbda3ed990db751e088e2337fb3ae895.png
# Saved to: side masked images/fbda3ed990db751e088e2337fb3ae895.png
# Processing: train/mask_left/fc152fc77b765c603802fa318b2e01d4.png
# Saved to: side masked images/fc152fc77b765c603802fa318b2e01d4.png
# Processing: train/mask_left/fc1f9044d4f8be1fa47de3714532b2a3.png
# Saved to: side masked images/fc1f9044d4f8be1fa47de3714532b2a3.png
# Processing: train/mask_left/fc3c184ead3ec2ef73c51448121eab87.png
# Saved to: side masked images/fc3c184ead3ec2ef73c51448121eab87.png
# Processing: train/mask_left/fc494e4b7d6761876beeccd239292969.png
# Saved to: side masked images/fc494e4b7d6761876beeccd239292969.png
# Processing: train/mask_left/fc4e9a5e374875c6dc8d1866dbf4bffb.png
# Saved to: side masked images/fc4e9a5e374875c6dc8d1866dbf4bffb.png
# Processing: train/mask_left/fc59cb12657606978eb8ec82ef79b13a.png
# Saved to: side masked images/fc59cb12657606978eb8ec82ef79b13a.png
# Processing: train/mask_left/fc5f1be06f640de544dff9143b24ae3a.png
# Saved to: side masked images/fc5f1be06f640de544dff9143b24ae3a.png
# Processing: train/mask_left/fc60575ab411f15c68f53be33ba95e00.png
# Saved to: side masked images/fc60575ab411f15c68f53be33ba95e00.png
# Processing: train/mask_left/fc78628ed34c26a8c3703767b69143ca.png
# Saved to: side masked images/fc78628ed34c26a8c3703767b69143ca.png
# Processing: train/mask_left/fc7b3decfb6d7ba04480764a954d84d7.png
# Saved to: side masked images/fc7b3decfb6d7ba04480764a954d84d7.png
# Processing: train/mask_left/fc8a0cad57144fe5b11e24fb4fc41b85.png
# Saved to: side masked images/fc8a0cad57144fe5b11e24fb4fc41b85.png
# Processing: train/mask_left/fc9857ad616bb0b7e2c6d9adcd1910ce.png
# Saved to: side masked images/fc9857ad616bb0b7e2c6d9adcd1910ce.png
# Processing: train/mask_left/fca5b2262dd464b82ed29e3610bdeadd.png
# Saved to: side masked images/fca5b2262dd464b82ed29e3610bdeadd.png
# Processing: train/mask_left/fcac8f838c10b952e29244819b4011db.png
# Saved to: side masked images/fcac8f838c10b952e29244819b4011db.png
# Processing: train/mask_left/fcc11efde77ee67b0810e4d96c549aba.png
# Saved to: side masked images/fcc11efde77ee67b0810e4d96c549aba.png
# Processing: train/mask_left/fceaaaa000a1db9dfcdd573e35cadcc1.png
# Saved to: side masked images/fceaaaa000a1db9dfcdd573e35cadcc1.png
# Processing: train/mask_left/fcf36aab2e72f4cdd06a5b7469ff550e.png
# Saved to: side masked images/fcf36aab2e72f4cdd06a5b7469ff550e.png
# Processing: train/mask_left/fcfc737101318c47a3ef9261c96bee92.png
# Saved to: side masked images/fcfc737101318c47a3ef9261c96bee92.png
# Processing: train/mask_left/fd02ebaf7e89d9c3abc7b1cc183b9739.png
# Saved to: side masked images/fd02ebaf7e89d9c3abc7b1cc183b9739.png
# Processing: train/mask_left/fd0e94bf1e1d57eb4538d433f77d30ae.png
# Saved to: side masked images/fd0e94bf1e1d57eb4538d433f77d30ae.png
# Processing: train/mask_left/fd2426a5ced78f6b34eb85e6407b5eb3.png
# Saved to: side masked images/fd2426a5ced78f6b34eb85e6407b5eb3.png
# Processing: train/mask_left/fd383aefa6814efb6a1ef42402677941.png
# Saved to: side masked images/fd383aefa6814efb6a1ef42402677941.png
# Processing: train/mask_left/fd39ee1731f5a32057cdbcb1b1c74f7c.png
# Saved to: side masked images/fd39ee1731f5a32057cdbcb1b1c74f7c.png
# Processing: train/mask_left/fd3b336515eb608666b010dd304272d3.png
# Saved to: side masked images/fd3b336515eb608666b010dd304272d3.png
# Processing: train/mask_left/fd478b41e52cf8d034af0db2b8f9a157.png
# Saved to: side masked images/fd478b41e52cf8d034af0db2b8f9a157.png
# Processing: train/mask_left/fd4f0c64200682d9bff4d42674792535.png
# Saved to: side masked images/fd4f0c64200682d9bff4d42674792535.png
# Processing: train/mask_left/fd5009ab7f9c7fdd3d0682dee397eb0c.png
# Saved to: side masked images/fd5009ab7f9c7fdd3d0682dee397eb0c.png
# Processing: train/mask_left/fd52157210de036b0fcad8ed5e7bd49c.png
# Saved to: side masked images/fd52157210de036b0fcad8ed5e7bd49c.png
# Processing: train/mask_left/fd5368e48d92df33e759d3c3add445f9.png
# Saved to: side masked images/fd5368e48d92df33e759d3c3add445f9.png
# Processing: train/mask_left/fd6a98f03a1f9afde784e8a93fa2dc3a.png
# Saved to: side masked images/fd6a98f03a1f9afde784e8a93fa2dc3a.png
# Processing: train/mask_left/fd6aae7c1756cb5b492a4466e380d782.png
# Saved to: side masked images/fd6aae7c1756cb5b492a4466e380d782.png
# Processing: train/mask_left/fd707b126ebee2e33ed03cc57f78f877.png
# Saved to: side masked images/fd707b126ebee2e33ed03cc57f78f877.png
# Processing: train/mask_left/fd72a06baffa30ead36564adc5fb9d06.png
# Saved to: side masked images/fd72a06baffa30ead36564adc5fb9d06.png
# Processing: train/mask_left/fd8f6522997a68e25a6ee14bc346e8af.png
# Saved to: side masked images/fd8f6522997a68e25a6ee14bc346e8af.png
# Processing: train/mask_left/fd9e501c7292d7ff266fe40a5d4af3bb.png
# Saved to: side masked images/fd9e501c7292d7ff266fe40a5d4af3bb.png
# Processing: train/mask_left/fdd9a56e7ecfda1dd63f611f70a46e3f.png
# Saved to: side masked images/fdd9a56e7ecfda1dd63f611f70a46e3f.png
# Processing: train/mask_left/fddcab248af430942197447cf6a13e9b.png
# Saved to: side masked images/fddcab248af430942197447cf6a13e9b.png
# Processing: train/mask_left/fde7fa244bdcadfe0101e8f3048e1c46.png
# Saved to: side masked images/fde7fa244bdcadfe0101e8f3048e1c46.png
# Processing: train/mask_left/fdedff1164b3eadb0a8db8a7b7c78c79.png
# Saved to: side masked images/fdedff1164b3eadb0a8db8a7b7c78c79.png
# Processing: train/mask_left/fdf61c01513ea3d5a8e7fa58cd0e5dea.png
# Saved to: side masked images/fdf61c01513ea3d5a8e7fa58cd0e5dea.png
# Processing: train/mask_left/fe0e6dc734026f2b0b0024221f11a6b7.png
# Saved to: side masked images/fe0e6dc734026f2b0b0024221f11a6b7.png
# Processing: train/mask_left/fe18d66886bc0fe8111118c0d4a5a855.png
# Saved to: side masked images/fe18d66886bc0fe8111118c0d4a5a855.png
# Processing: train/mask_left/fe236f8e07a1bd213941ceb99c353ebe.png
# Saved to: side masked images/fe236f8e07a1bd213941ceb99c353ebe.png
# Processing: train/mask_left/fe2594baea543b5e24b4771a49773098.png
# Saved to: side masked images/fe2594baea543b5e24b4771a49773098.png
# Processing: train/mask_left/fe27d1430750efae48fc57e95e735176.png
# Saved to: side masked images/fe27d1430750efae48fc57e95e735176.png
# Processing: train/mask_left/fe2d5106ade84014ec727fe11d7d4b82.png
# Saved to: side masked images/fe2d5106ade84014ec727fe11d7d4b82.png
# Processing: train/mask_left/fe2d79ae848271463aeeeca6e50be501.png
# Saved to: side masked images/fe2d79ae848271463aeeeca6e50be501.png
# Processing: train/mask_left/fe2ea4854405510e878755e0b427e11e.png
# Saved to: side masked images/fe2ea4854405510e878755e0b427e11e.png
# Processing: train/mask_left/fe32ecfed849b12468321ae4b0332fe0.png
# Saved to: side masked images/fe32ecfed849b12468321ae4b0332fe0.png
# Processing: train/mask_left/fe33781731cb82de37fa5326b07cae17.png
# Saved to: side masked images/fe33781731cb82de37fa5326b07cae17.png
# Processing: train/mask_left/fe35920c7b84cdea93cfc426aa00c8b1.png
# Saved to: side masked images/fe35920c7b84cdea93cfc426aa00c8b1.png
# Processing: train/mask_left/fe386748bb89af86c6e307d592c752a9.png
# Saved to: side masked images/fe386748bb89af86c6e307d592c752a9.png
# Processing: train/mask_left/fe3afc810f2f9171a6aa6e8f2d78270a.png
# Saved to: side masked images/fe3afc810f2f9171a6aa6e8f2d78270a.png
# Processing: train/mask_left/fe3f612bdf7afea81221e0a5ba83853a.png
# Saved to: side masked images/fe3f612bdf7afea81221e0a5ba83853a.png
# Processing: train/mask_left/fe422f124ddec8e6833f32af5708a0f2.png
# Saved to: side masked images/fe422f124ddec8e6833f32af5708a0f2.png
# Processing: train/mask_left/fe4eadbec5840fd5801270d02ab65ab1.png
# Saved to: side masked images/fe4eadbec5840fd5801270d02ab65ab1.png
# Processing: train/mask_left/fe53c9a5482f5b6ab895898ce8d036da.png
# Saved to: side masked images/fe53c9a5482f5b6ab895898ce8d036da.png
# Processing: train/mask_left/fe55d80955e8ac75a63d1ab22f63b505.png
# Saved to: side masked images/fe55d80955e8ac75a63d1ab22f63b505.png
# Processing: train/mask_left/fe589ad2d1fdfe539eead3530f230c92.png
# Saved to: side masked images/fe589ad2d1fdfe539eead3530f230c92.png
# Processing: train/mask_left/fe59f20c603c915d6014684d442e88e0.png
# Saved to: side masked images/fe59f20c603c915d6014684d442e88e0.png
# Processing: train/mask_left/fe5b7f30ba88fb28daf7f3f6eacc0628.png
# Saved to: side masked images/fe5b7f30ba88fb28daf7f3f6eacc0628.png
# Processing: train/mask_left/fe5ba70367827357d352ee0691669b93.png
# Saved to: side masked images/fe5ba70367827357d352ee0691669b93.png
# Processing: train/mask_left/fe79ab138d2f35a1bf31751c735d1447.png
# Saved to: side masked images/fe79ab138d2f35a1bf31751c735d1447.png
# Processing: train/mask_left/fe82e0504c5bc9384bc33e5eeabc5fab.png
# Saved to: side masked images/fe82e0504c5bc9384bc33e5eeabc5fab.png
# Processing: train/mask_left/fe967714e845eac0368f2622bcaebcfe.png
# Saved to: side masked images/fe967714e845eac0368f2622bcaebcfe.png
# Processing: train/mask_left/feacaefca7ac1143cf922b88764bb277.png
# Saved to: side masked images/feacaefca7ac1143cf922b88764bb277.png
# Processing: train/mask_left/fec4f8fcca82714e71cc052fb89d899e.png
# Saved to: side masked images/fec4f8fcca82714e71cc052fb89d899e.png
# Processing: train/mask_left/fec824d24e97c87fa397ecaf0447206d.png
# Saved to: side masked images/fec824d24e97c87fa397ecaf0447206d.png
# Processing: train/mask_left/fed36237038f8accec291af570ce5f85.png
# Saved to: side masked images/fed36237038f8accec291af570ce5f85.png
# Processing: train/mask_left/fede62ba4b738219ebc9521c95540e05.png
# Saved to: side masked images/fede62ba4b738219ebc9521c95540e05.png
# Processing: train/mask_left/fedf36877ca318716bbb493173d173bc.png
# Saved to: side masked images/fedf36877ca318716bbb493173d173bc.png
# Processing: train/mask_left/fee387c51a1cb973a4cdd98905baf628.png
# Saved to: side masked images/fee387c51a1cb973a4cdd98905baf628.png
# Processing: train/mask_left/fee42e42410aba6265aa9032af684122.png
# Saved to: side masked images/fee42e42410aba6265aa9032af684122.png
# Processing: train/mask_left/ff01063f84040a342b2d3d6e48e9a2b7.png
# Saved to: side masked images/ff01063f84040a342b2d3d6e48e9a2b7.png
# Processing: train/mask_left/ff0d41d2e381206890077044293d0155.png
# Saved to: side masked images/ff0d41d2e381206890077044293d0155.png
# Processing: train/mask_left/ff17aa70f613791efe23a2c909eafd07.png
# Saved to: side masked images/ff17aa70f613791efe23a2c909eafd07.png
# Processing: train/mask_left/ff17d0fd48c3fd9546048da59c93cd24.png
# Saved to: side masked images/ff17d0fd48c3fd9546048da59c93cd24.png
# Processing: train/mask_left/ff18ad0b397d41dc6a5546269f9732d8.png
# Saved to: side masked images/ff18ad0b397d41dc6a5546269f9732d8.png
# Processing: train/mask_left/ff341d1a1a5497c9ab6dd78da94a857b.png
# Saved to: side masked images/ff341d1a1a5497c9ab6dd78da94a857b.png
# Processing: train/mask_left/ff368f44af209f5fb76b518521c224d3.png
# Saved to: side masked images/ff368f44af209f5fb76b518521c224d3.png
# Processing: train/mask_left/ff371bfe0dbb37f38b2f8e0a0c3a1849.png
# Saved to: side masked images/ff371bfe0dbb37f38b2f8e0a0c3a1849.png
# Processing: train/mask_left/ff3add7018a292186945ef45d4bce9c2.png
# Saved to: side masked images/ff3add7018a292186945ef45d4bce9c2.png
# Processing: train/mask_left/ff3d63553765e41ac6cdc6c604084f4f.png
# Saved to: side masked images/ff3d63553765e41ac6cdc6c604084f4f.png
# Processing: train/mask_left/ff45fb0e946061a94b641bb48e6b6f7a.png
# Saved to: side masked images/ff45fb0e946061a94b641bb48e6b6f7a.png
# Processing: train/mask_left/ff50e77566cd7b18057f872a7ef9969e.png
# Saved to: side masked images/ff50e77566cd7b18057f872a7ef9969e.png
# Processing: train/mask_left/ff555d82ed48b38a4f7d6d1219f183f4.png
# Saved to: side masked images/ff555d82ed48b38a4f7d6d1219f183f4.png
# Processing: train/mask_left/ff5601f5522c19962e41e7f3e58e07b5.png
# Saved to: side masked images/ff5601f5522c19962e41e7f3e58e07b5.png
# Processing: train/mask_left/ff5969e5ebefaa344f4539ca0afcb660.png
# Saved to: side masked images/ff5969e5ebefaa344f4539ca0afcb660.png
# Processing: train/mask_left/ff66145d8c664a8616707eb1328e0980.png
# Saved to: side masked images/ff66145d8c664a8616707eb1328e0980.png
# Processing: train/mask_left/ff6e1e19536b2e1dca1d56cba6db80f2.png
# Saved to: side masked images/ff6e1e19536b2e1dca1d56cba6db80f2.png
# Processing: train/mask_left/ff74b0fc0c5ef4888c52e839e6d49767.png
# Saved to: side masked images/ff74b0fc0c5ef4888c52e839e6d49767.png
# Processing: train/mask_left/ff89a45dd6f75c9ddf5e55fbaecbb7e0.png
# Saved to: side masked images/ff89a45dd6f75c9ddf5e55fbaecbb7e0.png
# Processing: train/mask_left/ff8b0c7388b453b25a624ec612907886.png
# Saved to: side masked images/ff8b0c7388b453b25a624ec612907886.png
# Processing: train/mask_left/ff8f246b5a1747314287c8f4fa912166.png
# Saved to: side masked images/ff8f246b5a1747314287c8f4fa912166.png
# Processing: train/mask_left/ff9441a4ec01f78f4e30379519362708.png
# Saved to: side masked images/ff9441a4ec01f78f4e30379519362708.png
# Processing: train/mask_left/ff9f81b0d8676386f9517f4c148c1595.png
# Saved to: side masked images/ff9f81b0d8676386f9517f4c148c1595.png
# Processing: train/mask_left/ffa2813bcd9240836d06e425262bf867.png
# Saved to: side masked images/ffa2813bcd9240836d06e425262bf867.png
# Processing: train/mask_left/ffa9a517d9ce7825536da2bd9bf0acb4.png
# Saved to: side masked images/ffa9a517d9ce7825536da2bd9bf0acb4.png
# Processing: train/mask_left/ffac6fa3a75ae438da0b4ab63bafdf30.png
# Saved to: side masked images/ffac6fa3a75ae438da0b4ab63bafdf30.png
# Processing: train/mask_left/ffb67f522478f203fb64f16009e164e9.png
# Saved to: side masked images/ffb67f522478f203fb64f16009e164e9.png
# Processing: train/mask_left/ffb8aaa54ac7d5d3d0d6b2c069eac775.png
# Saved to: side masked images/ffb8aaa54ac7d5d3d0d6b2c069eac775.png
# Processing: train/mask_left/ffbd4d358d7d00e9818533b7159175c1.png
# Saved to: side masked images/ffbd4d358d7d00e9818533b7159175c1.png
# Processing: train/mask_left/ffbf68199a5d4887b9507a23a3ac2d97.png
# Saved to: side masked images/ffbf68199a5d4887b9507a23a3ac2d97.png
# Processing: train/mask_left/ffcb03ed7f6ea452648ebbac08024477.png
# Saved to: side masked images/ffcb03ed7f6ea452648ebbac08024477.png
# Processing: train/mask_left/ffcfce6a78a746c5c0f686cc484652aa.png
# Saved to: side masked images/ffcfce6a78a746c5c0f686cc484652aa.png
# Processing: train/mask_left/ffdc86f6b9ee01f57868fef07be6f889.png
# Saved to: side masked images/ffdc86f6b9ee01f57868fef07be6f889.png
# Processing: train/mask_left/ffe009aa411dc2e13d657f9717243928.png
# Saved to: side masked images/ffe009aa411dc2e13d657f9717243928.png
# Processing: train/mask_left/fffff15c2d2d77492da0d0d13e013774.png
# Saved to: side masked images/fffff15c2d2d77492da0d0d13e013774.png
# All images processed and saved in: side masked images

# %% [markdown]
# Step 5 - Compare S3 image count and local folder image count

# %%
# import os to work with directory listings
import os

# count how many image names were loaded from S3
num_s3_images = len(image_mask)  # get length of the list of S3 image names

# print the number of images found in S3
print("Number of image names from S3:", num_s3_images)

# list all files in the output folder
output_files = os.listdir(output_folder)  # get all file names in the output folder

# keep only files that end with .png (processed images)
output_images = [f for f in output_files if f.lower().endswith(".png")]  # filter only png files

# count how many processed images are in the folder
num_output_images = len(output_images)  # get length of the list of output images

# print the number of images in the output folder
print("Number of processed images in folder:", num_output_images)

# compare the counts from S3 and local folder
if num_s3_images == num_output_images:  # check if both counts are equal
    print("✅ Counts match: all images processed.")  # print success message
else:
    print("❌ Counts DO NOT match!")  # print mismatch message
    
    # calculate the difference between S3 and local counts
    diff = num_s3_images - num_output_images  # positive means missing, negative means extra
    
    # if diff is positive, some images are missing in the local folder
    if diff > 0:
        print(diff, "images are missing in the output folder.")  # report missing images
    else:
        # if diff is negative, there are extra images in the local folder
        print(-diff, "extra images are in the output folder.")  # report extra images
# Out:
# Number of image names from S3: 6134
# Number of processed images in folder: 6134
# ✅ Counts match: all images processed.

# %% [markdown]
# Step 6 - Check that file names match between S3 and local folder

# %%
# import os to work with file names and paths
import os

# create a set of base names (without extension) from S3 image list
s3_base_names = set(os.path.splitext(name)[0] for name in image_mask)

# list all files in the output folder
output_files = os.listdir(output_folder)

# keep only .png files from the output folder
output_images = [f for f in output_files if f.lower().endswith(".png")]

# create a set of base names (without extension) from local png files
local_base_names = set(os.path.splitext(name)[0] for name in output_images)

# print how many unique base names are in each set
print("Unique S3 base names:", len(s3_base_names))
print("Unique local base names:", len(local_base_names))

# check if both sets of base names are exactly the same
if s3_base_names == local_base_names:
    # if sets are equal, all file names match
    print("✅ File names match between S3 and local folder (ignoring extension).")
else:
    # if sets differ, there is some mismatch
    print("❌ File names do NOT match between S3 and local folder.")
    
    # find names present in S3 but missing locally
    missing_locally = s3_base_names - local_base_names
    # find names present locally but not in S3
    extra_locally = local_base_names - s3_base_names
    
    # if there are names missing in local folder, print them
    if missing_locally:
        print("\nNames in S3 but missing in local folder:")
        for name in sorted(missing_locally):
            print("  ", name)
    
    # if there are extra names in local folder, print them
    if extra_locally:
        print("\nNames in local folder but not in S3:")
        for name in sorted(extra_locally):
            print("  ", name)
# Out:
# Unique S3 base names: 6134
# Unique local base names: 6134
# ✅ File names match between S3 and local folder (ignoring extension).
